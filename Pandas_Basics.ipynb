# %% [markdown]
# <a href="https://colab.research.google.com/github/matheeshaw25/PyTorch-for-Deep-Learning---Zero-to-Mastery/blob/main/Pandas_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
A = [[1,2,3],[4,5,6],[7,8,9]]

# %%
type(A)
# Out:
# list

# %% [markdown]
# Loading into a DataFrame

# %%
B = pd.DataFrame(A,columns=['Col1','Col2','Col3'],index=['Ex1','Ex2','Ex3']) # naming the columns and naming the indexes
B
# Out:
#      Col1  Col2  Col3
# Ex1     1     2     3
# Ex2     4     5     6
# Ex3     7     8     9

# %% [markdown]
# To slice panda data frames  - use .iloc method

# %%
B.iloc[:,0:2] # all rows, first and second columns
# Out:
#      Col1  Col2
# Ex1     1     2
# Ex2     4     5
# Ex3     7     8

# %%
B.iloc[0:2,:]
# Out:
#      Col1  Col2  Col3
# Ex1     1     2     3
# Ex2     4     5     6

# %% [markdown]
# If you want to get data using labels you have to use ".loc" instead of ".iloc"

# %%
B.loc['Ex2','Col3']
# Out:
# 6

# %% [markdown]
# Replacing digits

# %%
 B.replace(9,100)
# Out:
#      Col1  Col2  Col3
# Ex1     1     2     3
# Ex2     4     5     6
# Ex3     7     8   100

# %% [markdown]
# Replacing several at once

# %%
B.replace({5:20,7:30}) # change 5 to 30 , change 7 to 30
# Out:
#      Col1  Col2  Col3
# Ex1     1     2     3
# Ex2     4    20     6
# Ex3    30     8     9

# %% [markdown]
# Dropping a column

# %%
C = B.drop('Col1',axis=1) #axis - 0  means rows, axis - 1 means columns
C
# Out:
#      Col2  Col3
# Ex1     2     3
# Ex2     5     6
# Ex3     8     9

# %%
B
# Out:
#      Col1  Col2  Col3
# Ex1     1     2     3
# Ex2     4     5     6
# Ex3     7     8     9
